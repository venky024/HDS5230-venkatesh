# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
df = pd.read_csv("diabetes_dataset.csv")
df = df.drop(columns=['Unnamed: 0'])
categorical_cols = df.select_dtypes(include=['object']).columns.tolist()
df = pd.get_dummies(df, columns=categorical_cols, drop_first=True)

# Define target and features
X = df.drop(columns=['HbA1c'])
y = df['HbA1c']

# Scale features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# Build a simple neural network
model = Sequential([
    Dense(32, input_shape=(X_train.shape[1],), activation='relu'),
    Dense(16, activation='relu'),
    Dense(1)
])

model.compile(optimizer='adam', loss='mse', metrics=['mae'])
model.fit(X_train, y_train, epochs=50, batch_size=16, validation_split=0.1)
loss, mae = model.evaluate(X_test, y_test)
print(f"Test MAE: {mae:.2f}")
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/50
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 43.1479 - mae: 5.4343 - val_loss: 11.1186 - val_mae: 2.8413
# Epoch 2/50
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 11.1427 - mae: 2.8528 - val_loss: 10.9664 - val_mae: 2.8373
# Epoch 3/50
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 10.6838 - mae: 2.7882 - val_loss: 10.9443 - val_mae: 2.8271
# Epoch 4/50
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 10.3369 - mae: 2.7543 - val_loss: 10.9338 - val_mae: 2.8345
# Epoch 5/50
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 10.3432 - mae: 2.7778 - val_loss: 10.8716 - val_mae: 2.8188
# Epoch 6/50
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 10.1183 - mae: 2.7357 - val_loss: 10.7778 - val_mae: 2.8134
# Epoch 7/50
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 9.8107 - mae: 2.7055 - val_loss: 10.7196 - val_mae: 2.8084
# Epoch 8/50
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 9.6126 - mae: 2.6568 - val_loss: 10.6587 - val_mae: 2.8006
# Epoch 9/50
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 9.8710 - mae: 2.7027 - val_loss: 10.7736 - val_mae: 2.8210
# Epoch 10/50
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 9.6305 - mae: 2.6690 - val_loss: 10.7292 - val_mae: 2.8070
# Epoch 11/50
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 9.6978 - mae: 2.6731 - val_loss: 10.7913 - val_mae: 2.8258
# Epoch 12/50
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 9.6986 - mae: 2.6784 - val_loss: 10.7528 - val_mae: 2.8160
# Epoch 13/50
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 9.6793 - mae: 2.6689 - val_loss: 10.7438 - val_mae: 2.8154
# Epoch 14/50
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 9.7429 - mae: 2.6872 - val_loss: 10.8209 - val_mae: 2.8223
# Epoch 15/50
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 9.6789 - mae: 2.6798 - val_loss: 10.9325 - val_mae: 2.8435
# Epoch 16/50
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 9.4567 - mae: 2.6488 - val_loss: 10.9721 - val_mae: 2.8390
# Epoch 17/50
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 9.4304 - mae: 2.6291 - val_loss: 10.9279 - val_mae: 2.8382
# Epoch 18/50
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 9.4092 - mae: 2.6336 - val_loss: 10.9285 - val_mae: 2.8407
# Epoch 19/50
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 9.3446 - mae: 2.6225 - val_loss: 11.2200 - val_mae: 2.8765
# Epoch 20/50
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 9.5110 - mae: 2.6434 - val_loss: 10.8396 - val_mae: 2.8364
# Epoch 21/50
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 9.4436 - mae: 2.6334 - val_loss: 10.9162 - val_mae: 2.8343
# Epoch 22/50
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 9.4163 - mae: 2.6397 - val_loss: 10.9964 - val_mae: 2.8338
# Epoch 23/50
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 9.2762 - mae: 2.6098 - val_loss: 10.9571 - val_mae: 2.8473
# Epoch 24/50
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 9.4595 - mae: 2.6316 - val_loss: 11.0107 - val_mae: 2.8423
# Epoch 25/50
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 9.0412 - mae: 2.5825 - val_loss: 11.0200 - val_mae: 2.8585
# Epoch 26/50
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 9.3129 - mae: 2.6190 - val_loss: 11.2655 - val_mae: 2.8849
# Epoch 27/50
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 9.2042 - mae: 2.5889 - val_loss: 11.2311 - val_mae: 2.8774
# Epoch 28/50
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 9.1613 - mae: 2.5962 - val_loss: 11.1718 - val_mae: 2.8760
# Epoch 29/50
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 9.0061 - mae: 2.5700 - val_loss: 11.2659 - val_mae: 2.8703
# Epoch 30/50
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 8.8589 - mae: 2.5426 - val_loss: 11.2312 - val_mae: 2.8736
# Epoch 31/50
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 8.9640 - mae: 2.5602 - val_loss: 11.2953 - val_mae: 2.8858
# Epoch 32/50
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 8.9801 - mae: 2.5502 - val_loss: 11.1816 - val_mae: 2.8649
# Epoch 33/50
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 8.8577 - mae: 2.5250 - val_loss: 11.2713 - val_mae: 2.8784
# Epoch 34/50
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 8.9537 - mae: 2.5485 - val_loss: 11.2663 - val_mae: 2.8775
# Epoch 35/50
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 8.8757 - mae: 2.5345 - val_loss: 11.1969 - val_mae: 2.8565
# Epoch 36/50
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 8.8516 - mae: 2.5284 - val_loss: 11.2802 - val_mae: 2.8708
# Epoch 37/50
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 8.9007 - mae: 2.5488 - val_loss: 11.5127 - val_mae: 2.8981
# Epoch 38/50
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 8.7701 - mae: 2.5186 - val_loss: 11.2393 - val_mae: 2.8625
# Epoch 39/50
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 8.8951 - mae: 2.5505 - val_loss: 11.3588 - val_mae: 2.8888
# Epoch 40/50
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 8.7826 - mae: 2.5194 - val_loss: 11.2656 - val_mae: 2.8718
# Epoch 41/50
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 8.7589 - mae: 2.5079 - val_loss: 11.2007 - val_mae: 2.8605
# Epoch 42/50
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 8.8167 - mae: 2.5336 - val_loss: 11.4234 - val_mae: 2.8897
# Epoch 43/50
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 8.8520 - mae: 2.5286 - val_loss: 11.3574 - val_mae: 2.8698
# Epoch 44/50
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 8.9300 - mae: 2.5483 - val_loss: 11.3122 - val_mae: 2.8726
# Epoch 45/50
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 8.6918 - mae: 2.5110 - val_loss: 11.5146 - val_mae: 2.8967
# Epoch 46/50
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 8.8201 - mae: 2.5270 - val_loss: 11.5606 - val_mae: 2.9062
# Epoch 47/50
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 8.5431 - mae: 2.4885 - val_loss: 11.7403 - val_mae: 2.9277
# Epoch 48/50
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 8.7058 - mae: 2.5087 - val_loss: 11.5370 - val_mae: 2.8944
# Epoch 49/50
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 8.6314 - mae: 2.5008 - val_loss: 11.7246 - val_mae: 2.9176
# Epoch 50/50
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 8.7011 - mae: 2.5093 - val_loss: 11.6132 - val_mae: 2.9053
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 11.4281 - mae: 2.8857
# Test MAE: 2.90
